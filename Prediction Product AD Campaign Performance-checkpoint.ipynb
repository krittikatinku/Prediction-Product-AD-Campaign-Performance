# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import joblib

# %%
#Load dataset:
df = pd.read_excel("C:\Prediction Product AD Campaign Performance\products_campaign_sales.xlsx")

# Preview the data
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Krittika\AppData\Local\Temp\ipykernel_12464\4052418158.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_excel("C:\Prediction Product AD Campaign Performance\products_campaign_sales.xlsx")
#    limit_infor  campaign_type  campaign_level  product_level  resource_amount  \
# 0            0              6               0              1                1
# 1            0              0               0              1                1
# 2            0              1               1              1                1
# 3            0              3               1              2                1
# 4            0              0               0              1                1
#
#    email_rate  price  discount_rate  hour_resouces  campaign_fee  orders
# 0        0.08  140.0           0.83             93           888    1981
# 1        0.10  144.0           0.75            150           836     986
# 2        0.12  149.0           0.84             86          1330    1416
# 3        0.12  141.0           0.82             95          2273    2368
# 4        0.10  146.0           0.59             73          1456    1529

# %%
#Data backup
data = df.copy()
df= data.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   limit_infor      731 non-null    int64
#  1   campaign_type    731 non-null    int64
#  2   campaign_level   731 non-null    int64
#  3   product_level    731 non-null    int64
#  4   resource_amount  731 non-null    int64
#  5   email_rate       731 non-null    float64
#  6   price            729 non-null    float64
#  7   discount_rate    731 non-null    float64
#  8   hour_resouces    731 non-null    int64
#  9   campaign_fee     731 non-null    int64
#  10  orders           731 non-null    int64
# dtypes: float64(3), int64(8)
# memory usage: 62.9 KB

# %%
#Duplicate
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [limit_infor, campaign_type, campaign_level, product_level, resource_amount, email_rate, price, discount_rate, hour_resouces, campaign_fee, orders]
# Index: []

# %%
#Null Values
df.isnull().sum()
# Out:
# limit_infor        0
# campaign_type      0
# campaign_level     0
# product_level      0
# resource_amount    0
# email_rate         0
# price              2
# discount_rate      0
# hour_resouces      0
# campaign_fee       0
# orders             0
# dtype: int64

# %%
df.shape
# Out:
# (731, 11)

# %%
#Count rows
print("No of rows:", df.shape[0])
#Count of columns
print("No of columns:",df.shape[0])

#Columns Name
Columns =df.columns.to_list()
print("Columns are:\n",Columns)
# Out:
# No of rows: 731
# No of columns: 731
# Columns are:
#  ['limit_infor', 'campaign_type', 'campaign_level', 'product_level', 'resource_amount', 'email_rate', 'price', 'discount_rate', 'hour_resouces', 'campaign_fee', 'orders']

# %%
#Duplicated
print("Count of duplicate:")
df.isnull().sum()
# Out:
# Count of duplicate:
# limit_infor        0
# campaign_type      0
# campaign_level     0
# product_level      0
# resource_amount    0
# email_rate         0
# price              2
# discount_rate      0
# hour_resouces      0
# campaign_fee       0
# orders             0
# dtype: int64

# %%
df.head()
# Out:
#    limit_infor  campaign_type  campaign_level  product_level  resource_amount  \
# 0            0              6               0              1                1
# 1            0              0               0              1                1
# 2            0              1               1              1                1
# 3            0              3               1              2                1
# 4            0              0               0              1                1
#
#    email_rate  price  discount_rate  hour_resouces  campaign_fee  orders
# 0        0.08  140.0           0.83             93           888    1981
# 1        0.10  144.0           0.75            150           836     986
# 2        0.12  149.0           0.84             86          1330    1416
# 3        0.12  141.0           0.82             95          2273    2368
# 4        0.10  146.0           0.59             73          1456    1529

# %%
abs(-5)
# Out:
# 5

# %%
#limit_infor: limits or restrictions associated with the marketing campaign or product.
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product."
}

column_descriptions
# Out:
# {'limit_infor': 'Limits or restrictions associated with the marketing campaign or product.'}

# %%
#campaign_type: type of marketing campaign, such as email, social media, print advertising,etc
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc."
}

for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")
# Out:
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.

# %%
#campaign_level: level or scale of the marketing campaign, for example, national, regional, or local.
print("campaign_level:",
      "Level or scale of the marketing campaign, for example, national, regional, or local.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local."
}

column_descriptions
for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")
# Out:
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.

# %%
#product_level: level or category of the product being marketed, such as high-end, mid-range, or budget
print("product_level:",
      "Level or category of the product being marketed, such as high-end, mid-range, or budget.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget."
}

column_descriptions

for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["product_level"] = "Level or category of the product being marketed, such as high-end, mid-range, or budget."
df.attrs
# Out:
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.'}

# %%
#resource_amount: resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
print("resource_amount:",
      "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign."
}

column_descriptions

for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["resource_amount"] = "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign."
df.attrs
# Out:
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.'}

# %%
#email_rate: email delivery rate or open rate.
print("email_rate:",
      "Email delivery rate or open rate.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.",
    "email_rate": "Email delivery rate or open rate."
}

column_descriptions
for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["email_rate"] = "Email delivery rate or open rate."
df.attrs
# Out:
# email_rate: Email delivery rate or open rate.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# email_rate: Email delivery rate or open rate.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.',
#  'email_rate': 'Email delivery rate or open rate.'}

# %%
#price: selling price of the product.
print("price:",
      "Selling price of the product.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.",
    "email_rate": "Email delivery rate or open rate.",
    "price": "Selling price of the product."
}

column_descriptions

for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["price"] = "Selling price of the product."
df.attrs
# Out:
# price: Selling price of the product.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# email_rate: Email delivery rate or open rate.
# price: Selling price of the product.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.',
#  'email_rate': 'Email delivery rate or open rate.',
#  'price': 'Selling price of the product.'}

# %%
#discount_rate: discounts or promotional offers associated with the product.
print("discount_rate:",
      "Discounts or promotional offers associated with the product.")
column_descriptions["discount_rate"] = "Discounts or promotional offers associated with the product."
column_descriptions

column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.",
    "email_rate": "Email delivery rate or open rate.",
    "price": "Selling price of the product.",
    "discount_rate": "Discounts or promotional offers associated with the product."
}
column_descriptions

df.attrs["discount_rate"] = "Discounts or promotional offers associated with the product."
df.attrs
# Out:
# discount_rate: Discounts or promotional offers associated with the product.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.',
#  'email_rate': 'Email delivery rate or open rate.',
#  'price': 'Selling price of the product.',
#  'discount_rate': 'Discounts or promotional offers associated with the product.'}

# %%
#hour_resources: the number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.
print("hour_resources:",
      "The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.",
    "email_rate": "Email delivery rate or open rate.",
    "price": "Selling price of the product.",
    "discount_rate": "Discounts or promotional offers associated with the product.",
    "hour_resources": "The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts."
}

column_descriptions
for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["hour_resources"] = (
    "The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts."
)

df.attrs
# Out:
# hour_resources: The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# email_rate: Email delivery rate or open rate.
# price: Selling price of the product.
# discount_rate: Discounts or promotional offers associated with the product.
# hour_resources: The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.',
#  'email_rate': 'Email delivery rate or open rate.',
#  'price': 'Selling price of the product.',
#  'discount_rate': 'Discounts or promotional offers associated with the product.',
#  'hour_resources': 'The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.'}

# %%
#campaign_fee: fees or costs associated with running the marketing campaign.
print("campaign_fee:",
      "Fees or costs associated with running the marketing campaign.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.",
    "email_rate": "Email delivery rate or open rate.",
    "price": "Selling price of the product.",
    "discount_rate": "Discounts or promotional offers associated with the product.",
    "hour_resources": "The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.",
    "campaign_fee": "Fees or costs associated with running the marketing campaign."
}

column_descriptions
for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["campaign_fee"] = "Fees or costs associated with running the marketing campaign."

df.attrs
# Out:
# campaign_fee: Fees or costs associated with running the marketing campaign.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# email_rate: Email delivery rate or open rate.
# price: Selling price of the product.
# discount_rate: Discounts or promotional offers associated with the product.
# hour_resources: The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.
# campaign_fee: Fees or costs associated with running the marketing campaign.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.',
#  'email_rate': 'Email delivery rate or open rate.',
#  'price': 'Selling price of the product.',
#  'discount_rate': 'Discounts or promotional offers associated with the product.',
#  'hour_resources': 'The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.',
#  'campaign_fee': 'Fees or costs associated with running the marketing campaign.'}

# %%
#orders: number of orders or sales generated for the product during the marketing campaign.
print("orders:",
      "Number of orders or sales generated for the product during the marketing campaign.")
column_descriptions = {
    "limit_infor": "Limits or restrictions associated with the marketing campaign or product.",
    "campaign_type": "Type of marketing campaign, such as email, social media, print advertising, etc.",
    "campaign_level": "Level or scale of the marketing campaign, for example, national, regional, or local.",
    "product_level": "Level or category of the product being marketed, such as high-end, mid-range, or budget.",
    "resource_amount": "Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.",
    "email_rate": "Email delivery rate or open rate.",
    "price": "Selling price of the product.",
    "discount_rate": "Discounts or promotional offers associated with the product.",
    "hour_resources": "The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.",
    "campaign_fee": "Fees or costs associated with running the marketing campaign.",
    "orders": "Number of orders or sales generated for the product during the marketing campaign."
}

column_descriptions
for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

df.attrs["orders"] = "Number of orders or sales generated for the product during the marketing campaign."

df.attrs
# Out:
# orders: Number of orders or sales generated for the product during the marketing campaign.
# limit_infor: Limits or restrictions associated with the marketing campaign or product.
# campaign_type: Type of marketing campaign, such as email, social media, print advertising, etc.
# campaign_level: Level or scale of the marketing campaign, for example, national, regional, or local.
# product_level: Level or category of the product being marketed, such as high-end, mid-range, or budget.
# resource_amount: Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.
# email_rate: Email delivery rate or open rate.
# price: Selling price of the product.
# discount_rate: Discounts or promotional offers associated with the product.
# hour_resources: The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.
# campaign_fee: Fees or costs associated with running the marketing campaign.
# orders: Number of orders or sales generated for the product during the marketing campaign.
# {'product_level': 'Level or category of the product being marketed, such as high-end, mid-range, or budget.',
#  'resource_amount': 'Resources (e.g., budget, personnel, or materials) allocated for the marketing campaign.',
#  'email_rate': 'Email delivery rate or open rate.',
#  'price': 'Selling price of the product.',
#  'discount_rate': 'Discounts or promotional offers associated with the product.',
#  'hour_resources': 'The number of labor hours or human resources dedicated to the marketing campaign or product sales efforts.',
#  'campaign_fee': 'Fees or costs associated with running the marketing campaign.',
#  'orders': 'Number of orders or sales generated for the product during the marketing campaign.'}
